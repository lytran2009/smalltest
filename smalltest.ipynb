# %% [markdown]
# ## Cach 1: co le viet duoc theo cach nay nhung van chua bit viet nhu the nao cho dung

# %%
class Person:
    def __init__(self, id_user, name, age, gender):
        self.id_user = id_user
        self.name = name
        self.age = age
        self.gender = gender
    
    def select_gender(self):
        if self.gender == 'male':
            print(self.id_user)
        else:
            pass

# %%
x = Person('123','ly',30,'female')
y = Person('456','ha',20,'male')

# %% [markdown]
# ## Cach 2: cach nay thi ra dung ket qua yeu cau cua de bai, nhung co le khong phai la phuong phap tot

# %%
import pandas as pd
user = {
    'id':['0','1','2','3'],
    'name' : ['ly', 'ha', 'tuan','trang'],
    'age' : [34, 30, 16,20],
    'gender' : ['female', 'female', 'male','male']
}

# %%
user_data = pd.DataFrame(user)

# %%
user_data
# Out:
#    age  gender id   name
# 0   34  female  0     ly
# 1   30  female  1     ha
# 2   16    male  2   tuan
# 3   20    male  3  trang

# %%
user_data[user_data.gender == 'male']
# Out:
#    age gender id   name
# 2   16   male  2   tuan
# 3   20   male  3  trang

# %%
user_data.age.sort_values(ascending=False)
# Out:
# 0    34
# 1    30
# 3    20
# 2    16
# Name: age, dtype: int64

# %% [markdown]
# ## Bai 1: Hieu duoc cach viet loop nay, nhung khong biet lam nhu the nao de no print ra 1 so thay vi bi duplicated nhu the nay

# %%
for i in range (5,101):
    for j in range (2,i):
        if i % j == 0:
            break
        else:
            print (i)
# Out:
# 5
# 5
# 5
# 7
# 7
# 7
# 7
# 7
# 9
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 15
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 21
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 25
# 25
# 25
# 27
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 33
# 35
# 35
# 35
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 39
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# ...
